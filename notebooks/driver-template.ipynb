# %%
import sqlite3
import pandas as pd
from pandas.core.frame import DataFrame
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

from matplotlib import pyplot as plt
from time import sleep

import matplotlib


# import gnuplotlib as gp
import numpy as np

import sys

# %%
pd.set_option('display.max_colwidth', None)

# %%
import requests

# %%
def get_df(f_path: str = "/home/kefei/.volttron/agents/"
                       "ba3caba2-2e44-49a3-a771-eaccf6b7bc3e/sqlhistorianagent-4.0.0/data/platform.historian.sqlite"
           ) -> pd.DataFrame:
    # f_path = "/home/kefei/.volttron/agents/85736715-3354-4b70-94d7-eb2ca6e88e48/sqlhistorianagent-4.0.0/data/platform.historian.sqlite"
    con = sqlite3.connect(f_path)

    # df = pd.read_sql_query("SELECT name FROM sqlite_schema WHERE type ='table' AND name NOT LIKE 'sqlite_%'", con)
    # df.head()

    df_data = pd.read_sql_query(sql="select * from data", con=con)
    # df_data

    df_topics = pd.read_sql_query(sql="select * from topics", con=con)
    # df_topics
    con.commit()  # to make sure refresh

    df_join = pd.merge(df_data, df_topics, on='topic_id')
    # df_join.head()

    return df_join

# %%
df = get_df()
df.tail()
# Out:
#                                      ts  topic_id  \
# 47691  2022-05-17T18:30:28.612468+00:00        80
# 47692  2022-05-17T18:30:33.584473+00:00        80
# 47693  2022-05-17T18:30:38.502511+00:00        80
# 47694  2022-05-17T18:30:43.538448+00:00        80
# 47695  2022-05-17T18:30:48.491823+00:00        80
#
#                                                                                                                                                                          value_string  \
# 47691                                         "{'activity': 'Compliment someone', 'type': 'social', 'participants': 2, 'price': 0, 'link': '', 'key': '9149470', 'accessibility': 0}"
# 47692  "{'activity': \"Text a friend you haven't talked to in a long time\", 'type': 'social', 'participants': 2, 'price': 0.05, 'link': '', 'key': '6081071', 'accessibility': 0.2}"
# 47693                    "{'activity': 'Play a game of tennis with a friend', 'type': 'social', 'participants': 2, 'price': 0.1, 'link': '', 'key': '1093640', 'accessibility': 0.4}"
# 47694                  "{'activity': 'Cook something together with someone', 'type': 'cooking', 'participants': 2, 'price': 0.3, 'link': '', 'key': '1799120', 'accessibility': 0.8}"
# 47695                    "{'activity': 'Play a game of tennis with a friend', 'type': 'social', 'participants': 2, 'price': 0.1, 'link': '', 'key': '1093640', 'accessibility': 0.4}"
#
#                                  topic_name  \
# 47691  campus/building/restapivalid/Catfact
# 47692  campus/building/restapivalid/Catfact
# 47693  campus/building/restapivalid/Catfact
# 47694  campus/building/restapivalid/Catfact
# 47695  campus/building/restapivalid/Catfact
#
#                                                               metadata
# 47691  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 47692  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 47693  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 47694  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 47695  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}

# %%
# inspect here
df = get_df()
df.sort_values('ts', ascending=False).head(8)
# Out:
#                                      ts  topic_id  \
# 47715  2022-05-17T18:31:38.492869+00:00        80
# 45594  2022-05-17T18:31:38.492869+00:00        79
# 45593  2022-05-17T18:31:33.540686+00:00        79
# 47714  2022-05-17T18:31:33.540686+00:00        80
# 45592  2022-05-17T18:31:28.566726+00:00        79
# 47713  2022-05-17T18:31:28.566726+00:00        80
# 45591  2022-05-17T18:31:23.557684+00:00        79
# 47712  2022-05-17T18:31:23.557684+00:00        80
#
#                                                                                                                                                                          value_string  \
# 47715                    "{'activity': 'Play a game of tennis with a friend', 'type': 'social', 'participants': 2, 'price': 0.1, 'link': '', 'key': '1093640', 'accessibility': 0.4}"
# 45594                                                                                                                                                                            true
# 45593                                                                                                                                                                           false
# 47714  "{'activity': \"Text a friend you haven't talked to in a long time\", 'type': 'social', 'participants': 2, 'price': 0.05, 'link': '', 'key': '6081071', 'accessibility': 0.2}"
# 45592                                                                                                                                                                           false
# 47713  "{'activity': \"Text a friend you haven't talked to in a long time\", 'type': 'social', 'participants': 2, 'price': 0.05, 'link': '', 'key': '6081071', 'accessibility': 0.2}"
# 45591                                                                                                                                                                            true
# 47712                              "{'activity': 'Go swimming with a friend', 'type': 'social', 'participants': 2, 'price': 0.1, 'link': '', 'key': '1505028', 'accessibility': 0.1}"
#
#                                    topic_name  \
# 47715    campus/building/restapivalid/Catfact
# 45594  campus/building/restapivalid/Heartbeat
# 45593  campus/building/restapivalid/Heartbeat
# 47714    campus/building/restapivalid/Catfact
# 45592  campus/building/restapivalid/Heartbeat
# 47713    campus/building/restapivalid/Catfact
# 45591  campus/building/restapivalid/Heartbeat
# 47712    campus/building/restapivalid/Catfact
#
#                                                               metadata
# 47715  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 45594       {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 45593       {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 47714  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 45592       {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 47713  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 45591       {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 47712  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}

# %%
df.sort_values('ts', ascending=False)[df.topic_id==74]
# Out:
# /tmp/ipykernel_20410/2667106004.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.sort_values('ts', ascending=False)[df.topic_id==74]
#                                      ts  topic_id  \
# 43383  2022-05-15T19:41:48.474325+00:00        74
# 43382  2022-05-15T19:41:43.621061+00:00        74
# 43381  2022-05-15T19:41:38.470222+00:00        74
# 43380  2022-05-15T19:41:33.478992+00:00        74
# 43379  2022-05-15T19:41:28.453468+00:00        74
# ...                                 ...       ...
# 43176  2022-05-14T19:03:03.439562+00:00        74
# 43175  2022-05-14T19:02:58.438984+00:00        74
# 43174  2022-05-14T19:02:53.465537+00:00        74
# 43173  2022-05-14T19:02:48.462299+00:00        74
# 43172  2022-05-14T19:02:43.499025+00:00        74
#
#                                                                                                                                                                                                                                                                                                                                                                value_string  \
# 43383                                                                                                                                                                                                              "{'activity': 'Donate to your local food bank', 'type': 'charity', 'participants': 1, 'price': 0.5, 'link': '', 'key': '4150284', 'accessibility': 0.8}"
# 43382                                                                                                                                                                                                               "{'activity': 'Catch up on world news', 'type': 'recreational', 'participants': 1, 'price': 0.05, 'link': '', 'key': '6596257', 'accessibility': 0.07}"
# 43381                                                                                                                                                                                                                              "{'activity': 'Go stargazing', 'type': 'relaxation', 'participants': 1, 'price': 0, 'link': '', 'key': '8832605', 'accessibility': 0.1}"
# 43380                                                                                                                                                                                     "{'activity': 'Start a family tree', 'type': 'social', 'participants': 1, 'price': 0, 'link': 'https://en.wikipedia.org/wiki/Family_tree', 'key': '6825484', 'accessibility': 1}"
# 43379                                                                                                                                                                      "{'activity': 'Donate blood at a local blood center', 'type': 'charity', 'participants': 1, 'price': 0, 'link': 'https://www.redcross.org/give-blood', 'key': '6509779', 'accessibility': 0.35}"
# ...                                                                                                                                                                                                                                                                                                                                                                     ...
# 43176  "Two members of the cat family are distinct from all others: the clouded leopard and the cheetah. The clouded leopard does not roar like other big cats, nor does it groom or rest like small cats. The cheetah is unique because it is a running cat; all others are leaping cats. They are leaping cats because they slowly stalk their prey and then leap on it."
# 43175                                                                                                                                      "Researchers believe the word \u201ctabby\u201d comes from Attabiyah, a neighborhood in Baghdad, Iraq. Tabbies got their name because their striped coats resembled the famous wavy patterns in the silk produced in this city."
# 43174                                                                                                                                                                                                                                                     "Cats can predict earthquakes. We humans are not 100% sure how they do it. There are several different theories."
# 43173                                                                                                                                                                                                                                                                    "A cat has approximately 60 to 80 million olfactory cells (a human has between 5 and 20 million)."
# 43172                                                                                                                                                                                           "Cats that live together sometimes rub each others heads to show that they have no intention of fighting. Young cats do this more often, especially when they are excited."
#
#                             topic_name  \
# 43383  campus/building/restapi/Catfact
# 43382  campus/building/restapi/Catfact
# 43381  campus/building/restapi/Catfact
# 43380  campus/building/restapi/Catfact
# 43379  campus/building/restapi/Catfact
# ...                                ...
# 43176  campus/building/restapi/Catfact
# 43175  campus/building/restapi/Catfact
# 43174  campus/building/restapi/Catfact
# 43173  campus/building/restapi/Catfact
# 43172  campus/building/restapi/Catfact
#
#                                                               metadata
# 43383  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43382  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43381  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43380  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43379  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# ...                                                                ...
# 43176  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43175  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43174  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43173  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43172  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
#
# [212 rows x 5 columns]

# %%
df.sort_values('ts', ascending=False)[df.topic_id==73]
# Out:
# /tmp/ipykernel_20410/3160910235.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.sort_values('ts', ascending=False)[df.topic_id==73]
#                                      ts  topic_id value_string  \
# 43171  2022-05-15T19:41:48.474325+00:00        73         true
# 43170  2022-05-15T19:41:43.621061+00:00        73         true
# 43169  2022-05-15T19:41:38.470222+00:00        73         true
# 43168  2022-05-15T19:41:33.478992+00:00        73        false
# 43167  2022-05-15T19:41:28.453468+00:00        73        false
# ...                                 ...       ...          ...
# 42964  2022-05-14T19:03:03.439562+00:00        73         true
# 42963  2022-05-14T19:02:58.438984+00:00        73         true
# 42962  2022-05-14T19:02:53.465537+00:00        73         true
# 42961  2022-05-14T19:02:48.462299+00:00        73         true
# 42960  2022-05-14T19:02:43.499025+00:00        73         true
#
#                               topic_name  \
# 43171  campus/building/restapi/Heartbeat
# 43170  campus/building/restapi/Heartbeat
# 43169  campus/building/restapi/Heartbeat
# 43168  campus/building/restapi/Heartbeat
# 43167  campus/building/restapi/Heartbeat
# ...                                  ...
# 42964  campus/building/restapi/Heartbeat
# 42963  campus/building/restapi/Heartbeat
# 42962  campus/building/restapi/Heartbeat
# 42961  campus/building/restapi/Heartbeat
# 42960  campus/building/restapi/Heartbeat
#
#                                                          metadata
# 43171  {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 43170  {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 43169  {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 43168  {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 43167  {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# ...                                                           ...
# 42964  {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 42963  {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 42962  {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 42961  {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 42960  {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
#
# [212 rows x 5 columns]

# %%
df[df.topic_id==74].metadata.values[0]
# Out:
# '{"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}'

# %%
df.metadata.unique()
# Out:
# array(['{"units": "F", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "Enumeration", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "On / Off", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "On/Off", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "waveform", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "PPM", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "%", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "1/0", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "1-0", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}'],
#       dtype=object)

# %%
# customer code

# %%
def get_cat_fact(url: str = "https://catfact.ninja/fact") -> str:
    '''
    REST API request
    Return a string (cat fact)

    EXAMPLE:

    Typical response:
    {'fact': "A cat's nose is as unique as a human's fingerprint.", 'length': 51}
    Return:
    "A cat's nose is as unique as a human's fingerprint."

    '''
    cat_fact: str  # return value
    response = requests.get(url)
    response_json: dict = response.json()
    cat_fact = response_json.get("fact")
    return cat_fact

# %%
get_cat_fact()
# Out:
# 'Cats spend nearly 1/3 of their waking hours cleaning themselves.'

# %%
def get_activity(url: str = "https://www.boredapi.com/api/activity?type=recreational&participants=1") -> str:
    '''
    REST API request
    Return a string (cat fact)

    EXAMPLE:

    Typical response:
    {'fact': "A cat's nose is as unique as a human's fingerprint.", 'length': 51}
    Return:
    "A cat's nose is as unique as a human's fingerprint."

    '''
    activity_info_str: str  # return value
    response = requests.get(url)
    response_json: dict = response.json()
    activity_info = response_json
    activity_info_str = str(response_json)
    return activity_info_str

# %%
get_activity()
# Out:
# "{'activity': 'Do a jigsaw puzzle', 'type': 'recreational', 'participants': 1, 'price': 0.1, 'link': 'https://en.wikipedia.org/wiki/Jigsaw_puzzle', 'key': '8550768', 'accessibility': 1}"
