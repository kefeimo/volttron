# %%
import sqlite3
import pandas as pd
from pandas.core.frame import DataFrame
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

from matplotlib import pyplot as plt
from time import sleep

import matplotlib


# import gnuplotlib as gp
import numpy as np

import sys

# %%
pd.set_option('display.max_colwidth', None)

# %%
import requests

# %%
def get_df(f_path: str = "/home/kefei/.volttron/agents/"
                       "ba3caba2-2e44-49a3-a771-eaccf6b7bc3e/sqlhistorianagent-4.0.0/data/platform.historian.sqlite"
           ) -> pd.DataFrame:
    # f_path = "/home/kefei/.volttron/agents/85736715-3354-4b70-94d7-eb2ca6e88e48/sqlhistorianagent-4.0.0/data/platform.historian.sqlite"
    con = sqlite3.connect(f_path)

    # df = pd.read_sql_query("SELECT name FROM sqlite_schema WHERE type ='table' AND name NOT LIKE 'sqlite_%'", con)
    # df.head()

    df_data = pd.read_sql_query(sql="select * from data", con=con)
    # df_data

    df_topics = pd.read_sql_query(sql="select * from topics", con=con)
    # df_topics
    con.commit()  # to make sure refresh

    df_join = pd.merge(df_data, df_topics, on='topic_id')
    # df_join.head()

    return df_join

# %%
df = get_df()
df.tail()
# Out:
#                                      ts  topic_id  \
# 43095  2022-05-14T23:36:03.513343+00:00        74
# 43096  2022-05-14T23:36:43.516594+00:00        74
# 43097  2022-05-14T23:36:48.449426+00:00        74
# 43098  2022-05-14T23:36:53.455603+00:00        74
# 43099  2022-05-14T23:36:58.524002+00:00        74
#
#                                             value_string  \
# 43095  "{'activity': 'Have a picnic with some friends...
# 43096  "{'activity': 'Have a picnic with some friends...
# 43097  "{'activity': 'Host a movie marathon with some...
# 43098  "{'activity': 'Go on a fishing trip with some ...
# 43099  "{'activity': 'Go on a fishing trip with some ...
#
#                             topic_name  \
# 43095  campus/building/restapi/Catfact
# 43096  campus/building/restapi/Catfact
# 43097  campus/building/restapi/Catfact
# 43098  campus/building/restapi/Catfact
# 43099  campus/building/restapi/Catfact
#
#                                                 metadata
# 43095  {"units": "No cat fact", "type": "integer", "t...
# 43096  {"units": "No cat fact", "type": "integer", "t...
# 43097  {"units": "No cat fact", "type": "integer", "t...
# 43098  {"units": "No cat fact", "type": "integer", "t...
# 43099  {"units": "No cat fact", "type": "integer", "t...

# %%
df = get_df()
df.sort_values('ts', ascending=False).head(8)
# Out:
#                                      ts  topic_id  \
# 43185  2022-05-15T04:46:58.483567+00:00        74
# 43072  2022-05-15T04:46:58.483567+00:00        73
# 43071  2022-05-15T04:46:53.432081+00:00        73
# 43184  2022-05-15T04:46:53.432081+00:00        74
# 43070  2022-05-15T04:46:48.464345+00:00        73
# 43183  2022-05-15T04:46:48.464345+00:00        74
# 43069  2022-05-15T04:46:43.487042+00:00        73
# 43182  2022-05-15T04:46:43.487042+00:00        74
#
#                                                                                                                                                                          value_string  \
# 43185         "{'activity': 'Give your pet ten minutes of focused attention', 'type': 'relaxation', 'participants': 1, 'price': 0, 'link': '', 'key': '9937387', 'accessibility': 0}"
# 43072                                                                                                                                                                            true
# 43071                                                                                                                                                                            true
# 43184                                          "{'activity': 'Make a budget', 'type': 'busywork', 'participants': 1, 'price': 0, 'link': '', 'key': '4379552', 'accessibility': 0.1}"
# 43070                                                                                                                                                                           false
# 43183  "{'activity': 'Make a scrapbook with pictures of your favorite memories', 'type': 'diy', 'participants': 1, 'price': 0.1, 'link': '', 'key': '5554174', 'accessibility': 0.1}"
# 43069                                                                                                                                                                           false
# 43182           "{'activity': 'Pull a harmless prank on one of your friends', 'type': 'social', 'participants': 1, 'price': 0.1, 'link': '', 'key': '1288934', 'accessibility': 0.2}"
#
#                               topic_name  \
# 43185    campus/building/restapi/Catfact
# 43072  campus/building/restapi/Heartbeat
# 43071  campus/building/restapi/Heartbeat
# 43184    campus/building/restapi/Catfact
# 43070  campus/building/restapi/Heartbeat
# 43183    campus/building/restapi/Catfact
# 43069  campus/building/restapi/Heartbeat
# 43182    campus/building/restapi/Catfact
#
#                                                               metadata
# 43185  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43072       {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 43071       {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 43184  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43070       {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 43183  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43069       {"units": "On/Off", "type": "integer", "tz": "US/Pacific"}
# 43182  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}

# %%
df.sort_values('ts', ascending=False)[df.topic_id==74]
# Out:
# /tmp/ipykernel_5984/2667106004.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.sort_values('ts', ascending=False)[df.topic_id==74]
#                                      ts  topic_id  \
# 43159  2022-05-15T04:33:13.451962+00:00        74
# 43158  2022-05-15T04:33:08.486390+00:00        74
# 43157  2022-05-15T04:33:03.532271+00:00        74
# 43156  2022-05-15T04:32:58.607268+00:00        74
# 43155  2022-05-15T04:32:53.538405+00:00        74
# ...                                 ...       ...
# 43064  2022-05-14T19:03:03.439562+00:00        74
# 43063  2022-05-14T19:02:58.438984+00:00        74
# 43062  2022-05-14T19:02:53.465537+00:00        74
# 43061  2022-05-14T19:02:48.462299+00:00        74
# 43060  2022-05-14T19:02:43.499025+00:00        74
#
#                                                                                                                                                                                                                                                                                                                                                                value_string  \
# 43159                                                                                                                                                                                            "{'activity': \"Plan a vacation you've always wanted to take\", 'type': 'relaxation', 'participants': 1, 'price': 0, 'link': '', 'key': '7265395', 'accessibility': 0.05}"
# 43158                                                                                                                                                                                                                  "{'activity': 'Visit a nearby museum', 'type': 'recreational', 'participants': 1, 'price': 0.2, 'link': '', 'key': '5490351', 'accessibility': 0.7}"
# 43157                                                                                                                                                                    "{'activity': 'Draft your living will', 'type': 'busywork', 'participants': 1, 'price': 0, 'link': 'https://www.investopedia.com/terms/l/livingwill.asp', 'key': '2360432', 'accessibility': 0.5}"
# 43156                                                                                                                                                                                "{'activity': \"Clean out your closet and donate the clothes you've outgrown\", 'type': 'charity', 'participants': 1, 'price': 0, 'link': '', 'key': '9026787', 'accessibility': 0.1}"
# 43155                                                                                                                                                                                 "{'activity': 'Write a thank you letter to an influential person in your life', 'type': 'social', 'participants': 1, 'price': 0, 'link': '', 'key': '4101229', 'accessibility': 0.1}"
# ...                                                                                                                                                                                                                                                                                                                                                                     ...
# 43064  "Two members of the cat family are distinct from all others: the clouded leopard and the cheetah. The clouded leopard does not roar like other big cats, nor does it groom or rest like small cats. The cheetah is unique because it is a running cat; all others are leaping cats. They are leaping cats because they slowly stalk their prey and then leap on it."
# 43063                                                                                                                                      "Researchers believe the word \u201ctabby\u201d comes from Attabiyah, a neighborhood in Baghdad, Iraq. Tabbies got their name because their striped coats resembled the famous wavy patterns in the silk produced in this city."
# 43062                                                                                                                                                                                                                                                     "Cats can predict earthquakes. We humans are not 100% sure how they do it. There are several different theories."
# 43061                                                                                                                                                                                                                                                                    "A cat has approximately 60 to 80 million olfactory cells (a human has between 5 and 20 million)."
# 43060                                                                                                                                                                                           "Cats that live together sometimes rub each others heads to show that they have no intention of fighting. Young cats do this more often, especially when they are excited."
#
#                             topic_name  \
# 43159  campus/building/restapi/Catfact
# 43158  campus/building/restapi/Catfact
# 43157  campus/building/restapi/Catfact
# 43156  campus/building/restapi/Catfact
# 43155  campus/building/restapi/Catfact
# ...                                ...
# 43064  campus/building/restapi/Catfact
# 43063  campus/building/restapi/Catfact
# 43062  campus/building/restapi/Catfact
# 43061  campus/building/restapi/Catfact
# 43060  campus/building/restapi/Catfact
#
#                                                               metadata
# 43159  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43158  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43157  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43156  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43155  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# ...                                                                ...
# 43064  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43063  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43062  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43061  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
# 43060  {"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}
#
# [100 rows x 5 columns]

# %%
df.sort_values('ts', ascending=False)[df.topic_id==73]
# Out:
# /tmp/ipykernel_5984/3160910235.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.sort_values('ts', ascending=False)[df.topic_id==73]
#                                      ts  topic_id value_string  \
# 43029  2022-05-14T23:36:58.524002+00:00        73         true
# 43028  2022-05-14T23:36:53.455603+00:00        73         true
# 43027  2022-05-14T23:36:48.449426+00:00        73         true
# 43026  2022-05-14T23:36:43.516594+00:00        73         true
# 43025  2022-05-14T23:36:03.513343+00:00        73         true
# ...                                 ...       ...          ...
# 42964  2022-05-14T19:03:03.439562+00:00        73         true
# 42963  2022-05-14T19:02:58.438984+00:00        73         true
# 42962  2022-05-14T19:02:53.465537+00:00        73         true
# 42961  2022-05-14T19:02:48.462299+00:00        73         true
# 42960  2022-05-14T19:02:43.499025+00:00        73         true
#
#                               topic_name  \
# 43029  campus/building/restapi/Heartbeat
# 43028  campus/building/restapi/Heartbeat
# 43027  campus/building/restapi/Heartbeat
# 43026  campus/building/restapi/Heartbeat
# 43025  campus/building/restapi/Heartbeat
# ...                                  ...
# 42964  campus/building/restapi/Heartbeat
# 42963  campus/building/restapi/Heartbeat
# 42962  campus/building/restapi/Heartbeat
# 42961  campus/building/restapi/Heartbeat
# 42960  campus/building/restapi/Heartbeat
#
#                                                 metadata
# 43029  {"units": "On/Off", "type": "integer", "tz": "...
# 43028  {"units": "On/Off", "type": "integer", "tz": "...
# 43027  {"units": "On/Off", "type": "integer", "tz": "...
# 43026  {"units": "On/Off", "type": "integer", "tz": "...
# 43025  {"units": "On/Off", "type": "integer", "tz": "...
# ...                                                  ...
# 42964  {"units": "On/Off", "type": "integer", "tz": "...
# 42963  {"units": "On/Off", "type": "integer", "tz": "...
# 42962  {"units": "On/Off", "type": "integer", "tz": "...
# 42961  {"units": "On/Off", "type": "integer", "tz": "...
# 42960  {"units": "On/Off", "type": "integer", "tz": "...
#
# [70 rows x 5 columns]

# %%
df[df.topic_id==74].metadata.values[0]
# Out:
# '{"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}'

# %%
df.metadata.unique()
# Out:
# array(['{"units": "F", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "Enumeration", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "On / Off", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "On/Off", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "waveform", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "PPM", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "%", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "1/0", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "1-0", "type": "integer", "tz": "US/Pacific"}',
#        '{"units": "No cat fact", "type": "integer", "tz": "US/Pacific"}'],
#       dtype=object)

# %%
# customer code

# %%
def get_cat_fact(url: str = "https://catfact.ninja/fact") -> str:
    '''
    REST API request
    Return a string (cat fact)

    EXAMPLE:

    Typical response:
    {'fact': "A cat's nose is as unique as a human's fingerprint.", 'length': 51}
    Return:
    "A cat's nose is as unique as a human's fingerprint."

    '''
    cat_fact: str  # return value
    response = requests.get(url)
    response_json: dict = response.json()
    cat_fact = response_json.get("fact")
    return cat_fact

# %%
get_cat_fact()
# Out:
# 'The ancestor of all domestic cats is the African Wild Cat which still exists today.'

# %%
def get_activity(url: str = "https://www.boredapi.com/api/activity?type=recreational&participants=1") -> str:
    '''
    REST API request
    Return a string (cat fact)

    EXAMPLE:

    Typical response:
    {'fact': "A cat's nose is as unique as a human's fingerprint.", 'length': 51}
    Return:
    "A cat's nose is as unique as a human's fingerprint."

    '''
    activity_info_str: str  # return value
    response = requests.get(url)
    response_json: dict = response.json()
    activity_info = response_json
    activity_info_str = str(response_json)
    return activity_info_str

# %%
get_activity()
# Out:
# "{'activity': 'Do a jigsaw puzzle', 'type': 'recreational', 'participants': 1, 'price': 0.1, 'link': 'https://en.wikipedia.org/wiki/Jigsaw_puzzle', 'key': '8550768', 'accessibility': 1}"
