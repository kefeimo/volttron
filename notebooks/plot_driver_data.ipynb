# %%
import sqlite3
import pandas as pd
from pandas.core.frame import DataFrame
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.options.mode.chained_assignment = None

from matplotlib import pyplot as plt
from time import sleep

import matplotlib


# import gnuplotlib as gp
import numpy as np

import sys

# %%
def get_df(f_path: str = "/home/kefei/.volttron/agents/"
                       "ba3caba2-2e44-49a3-a771-eaccf6b7bc3e/sqlhistorianagent-4.0.0/data/platform.historian.sqlite"
           ) -> pd.DataFrame:
    # f_path = "/home/kefei/.volttron/agents/85736715-3354-4b70-94d7-eb2ca6e88e48/sqlhistorianagent-4.0.0/data/platform.historian.sqlite"
    con = sqlite3.connect(f_path)

    # df = pd.read_sql_query("SELECT name FROM sqlite_schema WHERE type ='table' AND name NOT LIKE 'sqlite_%'", con)
    # df.head()

    df_data = pd.read_sql_query(sql="select * from data", con=con)
    # df_data

    df_topics = pd.read_sql_query(sql="select * from topics", con=con)
    # df_topics
    con.commit()  # to make sure refresh

    df_join = pd.merge(df_data, df_topics, on='topic_id')
    # df_join.head()

    return df_join


# def get_df_plot(df_join: DataFrame, 
#                 topic_name: str = r"campus/building/fake/EKG_Cos",
#          ) -> DataFrame:
    
# #     df_join["topic_name_l4"] = df_join.topic_name.apply(lambda x: x.split("/")[-1])
#     # df_join.head()

# #     df_cos = df_join[df_join.topic_id == 24] # TODO: make it parameterized
#     df_cos = df_join[df_join.topic_name == topic_name] # TODO: better, but change the variable name later.
#     if not df_cos:
#         return pd.DataFrame({})

#     # pd.to_datetime(df_cos.ts)
#     df_cos_ts = df_cos[["ts", "value_string"]]
#     df_cos_ts.ts = pd.to_datetime(df_cos.ts)
# #     df_cos_ts.value_string = df_cos_ts.value_string.astype(float)
#     df_cos_ts.value_string = df_cos_ts.value_string.apply(lambda x: pd.to_numeric(x, errors='coerce'))
#     df_cos_ts.set_index('ts', inplace=True)
#     # df_cos_ts.info()

#     # only plot last 1 minute
#     # TODO: need to make the time range adaptable to sampling rate
#     last_index = df_cos_ts.index[-1]
#     last_index
#     last_index - pd.Timedelta("1 minute")
#     # df_cos_ts[last_index - pd.Timedelta("1 minute"):].plot()

#     df_plot = df_cos_ts[last_index - pd.Timedelta("1 minute"):]

#     return df_plot


def plot(df_plot: DataFrame) -> None:

    plt.rcParams["figure.figsize"] = [7.50, 3.50]
    plt.rcParams["figure.autolayout"] = True
    # plt.plot(df_plot)
    # plt.show()

    plt.plot(df_plot)
    plt.draw()
    # plt.pause(1)
    plt.clf()


def plot_terminal(df_plot: DataFrame) -> None:
    matplotlib.use('module://drawilleplot')

    plt.rcParams["figure.figsize"] = [7.50/2, 3.50/4]
    plt.rcParams["figure.autolayout"] = True
    # plt.plot(df_plot)
    # plt.show()

    # gp.plot(df_plot)
    plt.plot(df_plot)
    plt.show()
    # plt.pause(1)
    # plt.close()
    plt.clf()

# %%
def get_df_plot(df_join: DataFrame, 
                topic_name: str = r"campus/building/fake/EKG_Cos",
         ) -> DataFrame:
    
#     df_join["topic_name_l4"] = df_join.topic_name.apply(lambda x: x.split("/")[-1])
    # df_join.head()

#     df_cos = df_join[df_join.topic_id == 24] # TODO: make it parameterized
    df_cos = df_join[df_join.topic_name == topic_name] # TODO: better, but change the variable name later.
    if df_cos.isna().all().all():
        return df_cos

    # pd.to_datetime(df_cos.ts)
    df_cos_ts = df_cos[["ts", "value_string"]]
    df_cos_ts.ts = pd.to_datetime(df_cos.ts)
#     df_cos_ts.value_string = df_cos_ts.value_string.astype(float)
    df_cos_ts.value_string = df_cos_ts.value_string.apply(lambda x: pd.to_numeric(x, errors='coerce'))
    df_cos_ts.set_index('ts', inplace=True)
    # df_cos_ts.info()

    # only plot last 1 minute
    # TODO: need to make the time range adaptable to sampling rate
    last_index = df_cos_ts.index[-1]
    last_index
    last_index - pd.Timedelta("1 minute")
    # df_cos_ts[last_index - pd.Timedelta("1 minute"):].plot()

    df_plot = df_cos_ts[last_index - pd.Timedelta("1 minute"):]

    return df_plot

# %%
df = get_df()  # TODO: make it parameterized
df.head()
# Out:
#                                  ts  topic_id value_string  \
# 0  2022-05-09T19:53:35.009729+00:00         1         50.0
# 1  2022-05-09T19:53:40.010361+00:00         1         50.0
# 2  2022-05-09T19:53:45.007784+00:00         1         50.0
# 3  2022-05-09T19:53:50.009642+00:00         1         50.0
# 4  2022-05-09T19:53:55.013768+00:00         1         50.0
#
#                                           topic_name  \
# 0  fake-campus/fake-building/fake-device/OutsideA...
# 1  fake-campus/fake-building/fake-device/OutsideA...
# 2  fake-campus/fake-building/fake-device/OutsideA...
# 3  fake-campus/fake-building/fake-device/OutsideA...
# 4  fake-campus/fake-building/fake-device/OutsideA...
#
#                                             metadata
# 0  {"units": "F", "type": "integer", "tz": "US/Pa...
# 1  {"units": "F", "type": "integer", "tz": "US/Pa...
# 2  {"units": "F", "type": "integer", "tz": "US/Pa...
# 3  {"units": "F", "type": "integer", "tz": "US/Pa...
# 4  {"units": "F", "type": "integer", "tz": "US/Pa...

# %%
df = get_df()  # TODO: make it parameterized
df_join = df.copy()

topic_name = r"campus/building/fake/EKG_Co"
df_cos = df_join[df_join.topic_name == topic_name] # TODO: better, but change the variable name later.
df_cos
# if not df_cos:
# #     return pd.DataFrame({})
#     pass


#     # pd.to_datetime(df_cos.ts)
#     df_cos_ts = df_cos[["ts", "value_string"]]
#     df_cos_ts.ts = pd.to_datetime(df_cos.ts)
# Out:
# Empty DataFrame
# Columns: [ts, topic_id, value_string, topic_name, metadata]
# Index: []

# %%
df_join[df_join.topic_name.str.contains("fake")]
# Out:
#                                      ts  topic_id          value_string  \
# 0      2022-05-09T19:53:35.009729+00:00         1                  50.0
# 1      2022-05-09T19:53:40.010361+00:00         1                  50.0
# 2      2022-05-09T19:53:45.007784+00:00         1                  50.0
# 3      2022-05-09T19:53:50.009642+00:00         1                  50.0
# 4      2022-05-09T19:53:55.013768+00:00         1                  50.0
# ...                                 ...       ...                   ...
# 41443  2022-05-13T20:15:50.003032+00:00        48   -0.8660254037844386
# 41444  2022-05-13T20:15:55.004146+00:00        48  -0.49999999999999967
# 41445  2022-05-13T20:16:00.003610+00:00        48                   0.0
# 41446  2022-05-13T20:16:05.002105+00:00        48   0.49999999999999994
# 41447  2022-05-13T20:16:10.001292+00:00        48    0.8660254037844386
#
#                                               topic_name  \
# 0      fake-campus/fake-building/fake-device/OutsideA...
# 1      fake-campus/fake-building/fake-device/OutsideA...
# 2      fake-campus/fake-building/fake-device/OutsideA...
# 3      fake-campus/fake-building/fake-device/OutsideA...
# 4      fake-campus/fake-building/fake-device/OutsideA...
# ...                                                  ...
# 41443                       campus/building/fake/EKG_Cos
# 41444                       campus/building/fake/EKG_Cos
# 41445                       campus/building/fake/EKG_Cos
# 41446                       campus/building/fake/EKG_Cos
# 41447                       campus/building/fake/EKG_Cos
#
#                                                 metadata
# 0      {"units": "F", "type": "integer", "tz": "US/Pa...
# 1      {"units": "F", "type": "integer", "tz": "US/Pa...
# 2      {"units": "F", "type": "integer", "tz": "US/Pa...
# 3      {"units": "F", "type": "integer", "tz": "US/Pa...
# 4      {"units": "F", "type": "integer", "tz": "US/Pa...
# ...                                                  ...
# 41443  {"units": "1-0", "type": "integer", "tz": "US/...
# 41444  {"units": "1-0", "type": "integer", "tz": "US/...
# 41445  {"units": "1-0", "type": "integer", "tz": "US/...
# 41446  {"units": "1-0", "type": "integer", "tz": "US/...
# 41447  {"units": "1-0", "type": "integer", "tz": "US/...
#
# [41448 rows x 5 columns]

# %%
df_cos.isna().all().all()
# Out:
# True

# %%
df_join[df_join.topic_name_l4=="EKG_Cos"]
# Out:
#                                      ts  topic_id          value_string  \
# 15019  2022-05-09T19:53:35.009729+00:00        24   -0.4999999999999997
# 15020  2022-05-09T19:53:40.010361+00:00        24   -0.8660254037844384
# 15021  2022-05-09T19:53:45.007784+00:00        24                  -1.0
# 15022  2022-05-09T19:53:50.009642+00:00        24   -0.8660254037844386
# 15023  2022-05-09T19:53:55.013768+00:00        24  -0.49999999999999967
# ...                                 ...       ...                   ...
# 41443  2022-05-13T20:15:50.003032+00:00        48   -0.8660254037844386
# 41444  2022-05-13T20:15:55.004146+00:00        48  -0.49999999999999967
# 41445  2022-05-13T20:16:00.003610+00:00        48                   0.0
# 41446  2022-05-13T20:16:05.002105+00:00        48   0.49999999999999994
# 41447  2022-05-13T20:16:10.001292+00:00        48    0.8660254037844386
#
#                                           topic_name  \
# 15019  fake-campus/fake-building/fake-device/EKG_Cos
# 15020  fake-campus/fake-building/fake-device/EKG_Cos
# 15021  fake-campus/fake-building/fake-device/EKG_Cos
# 15022  fake-campus/fake-building/fake-device/EKG_Cos
# 15023  fake-campus/fake-building/fake-device/EKG_Cos
# ...                                              ...
# 41443                   campus/building/fake/EKG_Cos
# 41444                   campus/building/fake/EKG_Cos
# 41445                   campus/building/fake/EKG_Cos
# 41446                   campus/building/fake/EKG_Cos
# 41447                   campus/building/fake/EKG_Cos
#
#                                                 metadata topic_name_l4
# 15019  {"units": "1-0", "type": "integer", "tz": "US/...       EKG_Cos
# 15020  {"units": "1-0", "type": "integer", "tz": "US/...       EKG_Cos
# 15021  {"units": "1-0", "type": "integer", "tz": "US/...       EKG_Cos
# 15022  {"units": "1-0", "type": "integer", "tz": "US/...       EKG_Cos
# 15023  {"units": "1-0", "type": "integer", "tz": "US/...       EKG_Cos
# ...                                                  ...           ...
# 41443  {"units": "1-0", "type": "integer", "tz": "US/...       EKG_Cos
# 41444  {"units": "1-0", "type": "integer", "tz": "US/...       EKG_Cos
# 41445  {"units": "1-0", "type": "integer", "tz": "US/...       EKG_Cos
# 41446  {"units": "1-0", "type": "integer", "tz": "US/...       EKG_Cos
# 41447  {"units": "1-0", "type": "integer", "tz": "US/...       EKG_Cos
#
# [1727 rows x 6 columns]

# %%
if __name__ == "__main__":
    sys.argv[1] = "/home/kefei/.volttron/agents/"
    "ba3caba2-2e44-49a3-a771-eaccf6b7bc3e/sqlhistorianagent-4.0.0/"
    "data/platform.historian.sqlite"
    sys.argv[2] = r"campus/building/fake/EKG_Cos"
#     sys.argv[2] = r"EKG_Cos"
    
    # TODO add input validation
    
    while True:
        df = get_df(f_path=sys.argv[1])  # TODO: make it parameterized
        df_plot = get_df_plot(df_join=df,
                              topic_name=sys.argv[2],
                             )
        # plot(df_plot)
        plot_terminal(df_plot)
        sleep(2)

        # plot_test()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
#       6 #     sys.argv[2] = r"EKG_Cos"
#       7
#       8     # TODO add input validation
#      10     while True:
# ---> 11         df = get_df(f_path=sys.argv[1])  # TODO: make it parameterized
#      12         df_plot = get_df_plot(df_join=df,
#      13                               topic_name=sys.argv[2],
#      14                              )
#      15         # plot(df_plot)
#
# Input In [24], in get_df(f_path)
#       1 def get_df(f_path: str = "/home/kefei/.volttron/agents/"
#       2                        "ba3caba2-2e44-49a3-a771-eaccf6b7bc3e/sqlhistorianagent-4.0.0/data/platform.historian.sqlite"
#       3            ) -> pd.DataFrame:
#       4     # f_path = "/home/kefei/.volttron/agents/85736715-3354-4b70-94d7-eb2ca6e88e48/sqlhistorianagent-4.0.0/data/platform.historian.sqlite"
# ----> 5     con = sqlite3.connect(f_path)
#       7     # df = pd.read_sql_query("SELECT name FROM sqlite_schema WHERE type ='table' AND name NOT LIKE 'sqlite_%'", con)
#       8     # df.head()
#      10     df_data = pd.read_sql_query(sql="select * from data", con=con)
#
# OperationalError: unable to open database file

# %%
if __name__ == "__main__":
#     sys.argv[0] = "/home/kefei/.volttron/agents/"
#     "ba3caba2-2e44-49a3-a771-eaccf6b7bc3e/sqlhistorianagent-4.0.0/"
#     "data/platform.historian.sqlite"
#     sys.argv[1] = r"fake-campus/fake-building/fake-device/EKG_Cos"
# #     sys.argv[2] = r"EKG_Cos"
    
    # TODO add input validation
    
    while True:
        df = get_df()  # TODO: make it parameterized
        df_plot = get_df_plot(df_join=df,
                              
                             )
        # plot(df_plot)
        plot_terminal(df_plot)
        sleep(2)

        # plot_test()
# Out:
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⣿⠉⠉⠉⠹⠟⠛⠛⠛⠛⠛⠉⠉⠛⠛⠛⠛⠛⠻⠿⠯⢭⣭⣉⣉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⢉⣉⣩⣭⠭⠿⠏⠉⠉⠉⣽
# ⠀⠀⠀⠀1⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠉⠉⠛⠳⠶⢤⣄⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣤⠴⠖⠛⠋⠉⠉⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠙⠛⠲⠦⣤⣄⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⣤⡴⠶⠚⠋⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀0⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠙⠛⠲⠶⠤⣤⣄⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣤⡤⠴⠶⠚⠛⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠶⠿⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⣤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠭⠭⡭⠽⠿⠿⠿⠷⠶⠶⠶⠿⠿⠿⠿⠭⣭⠭⠥⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⣤⠤⠤⠤⠽
# −1⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛
#
#
# ⠀⠀⠀⠀20:15:10⠀⠀⠀⠀⠀⠀⠀20:15:20⠀⠀⠀⠀⠀⠀20:15:30⠀⠀⠀⠀⠀⠀⠀20:15:40⠀⠀⠀⠀⠀⠀20:15:50⠀⠀⠀⠀⠀⠀20:16:00⠀⠀⠀⠀⠀⠀⠀20:16:10
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⣿⠉⠉⠉⠹⠿⠛⠛⠛⠛⠛⠋⠙⠛⠛⠛⠛⠛⠿⠿⠯⢭⣭⣉⣉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⢉⣉⣩⣭⠭⠿⠏⠉⠉⠉⣽
# ⠀⠀⠀⠀1⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠉⠉⠛⠲⠶⢤⣄⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣤⠴⠶⠛⠋⠉⠉⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠙⠛⠲⠦⣤⣄⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⣤⡤⠶⠚⠛⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀0⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠙⠓⠲⠶⢤⣤⣄⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣤⡤⠴⠶⠚⠛⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠶⠿⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⣤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠭⠭⡭⠽⠿⠿⠿⠷⠶⠶⠶⠿⠿⠿⠿⠭⣭⠭⠥⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⣤⠤⠤⠤⠽
# −1⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛
#
#
# ⠀⠀⠀⠀20:15:10⠀⠀⠀⠀⠀⠀⠀20:15:20⠀⠀⠀⠀⠀⠀20:15:30⠀⠀⠀⠀⠀⠀⠀20:15:40⠀⠀⠀⠀⠀⠀20:15:50⠀⠀⠀⠀⠀⠀20:16:00⠀⠀⠀⠀⠀⠀⠀20:16:10
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⣿⠉⠉⠉⠹⠿⠛⠛⠛⠛⠛⠋⠙⠛⠛⠛⠛⠛⠿⠿⠯⢭⣭⣉⣉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⢉⣉⣩⣭⠭⠿⠏⠉⠉⠉⣽
# ⠀⠀⠀⠀1⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠉⠉⠛⠲⠶⢤⣄⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣤⠴⠶⠛⠋⠉⠉⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠙⠛⠲⠦⣤⣄⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⣤⡤⠶⠚⠛⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀0⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠙⠓⠲⠶⢤⣤⣄⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣤⡤⠴⠶⠚⠛⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠶⠿⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⣤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠭⠭⡭⠽⠿⠿⠿⠷⠶⠶⠶⠿⠿⠿⠿⠭⣭⠭⠥⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⣤⠤⠤⠤⠽
# −1⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛
#
#
# ⠀⠀⠀⠀20:15:10⠀⠀⠀⠀⠀⠀⠀20:15:20⠀⠀⠀⠀⠀⠀20:15:30⠀⠀⠀⠀⠀⠀⠀20:15:40⠀⠀⠀⠀⠀⠀20:15:50⠀⠀⠀⠀⠀⠀20:16:00⠀⠀⠀⠀⠀⠀⠀20:16:10
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⣿⠉⠉⠉⠹⠿⠛⠛⠛⠛⠛⠋⠙⠛⠛⠛⠛⠛⠿⠿⠯⢭⣭⣉⣉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⢉⣉⣩⣭⠭⠿⠏⠉⠉⠉⣽
# ⠀⠀⠀⠀1⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠉⠉⠛⠲⠶⢤⣄⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣤⠴⠶⠛⠋⠉⠉⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠙⠛⠲⠦⣤⣄⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⣤⡤⠶⠚⠛⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀0⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠙⠓⠲⠶⢤⣤⣄⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣤⡤⠴⠶⠚⠛⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠶⠿⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⣤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠭⠭⡭⠽⠿⠿⠿⠷⠶⠶⠶⠿⠿⠿⠿⠭⣭⠭⠥⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⣤⠤⠤⠤⠽
# −1⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛
#
#
# ⠀⠀⠀⠀20:15:10⠀⠀⠀⠀⠀⠀⠀20:15:20⠀⠀⠀⠀⠀⠀20:15:30⠀⠀⠀⠀⠀⠀⠀20:15:40⠀⠀⠀⠀⠀⠀20:15:50⠀⠀⠀⠀⠀⠀20:16:00⠀⠀⠀⠀⠀⠀⠀20:16:10
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⣿⠉⠉⠉⠹⠿⠛⠛⠛⠛⠛⠋⠙⠛⠛⠛⠛⠛⠿⠿⠯⢭⣭⣉⣉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⢉⣉⣩⣭⠭⠿⠏⠉⠉⠉⣽
# ⠀⠀⠀⠀1⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠉⠉⠛⠲⠶⢤⣄⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣤⠴⠶⠛⠋⠉⠉⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠙⠛⠲⠦⣤⣄⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⣤⡤⠶⠚⠛⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀0⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠙⠓⠲⠶⢤⣤⣄⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣤⡤⠴⠶⠚⠛⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠶⠿⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⣤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠭⠭⡭⠽⠿⠿⠿⠷⠶⠶⠶⠿⠿⠿⠿⠭⣭⠭⠥⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⣤⠤⠤⠤⠽
# −1⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛
#
#
# ⠀⠀⠀⠀20:15:10⠀⠀⠀⠀⠀⠀⠀20:15:20⠀⠀⠀⠀⠀⠀20:15:30⠀⠀⠀⠀⠀⠀⠀20:15:40⠀⠀⠀⠀⠀⠀20:15:50⠀⠀⠀⠀⠀⠀20:16:00⠀⠀⠀⠀⠀⠀⠀20:16:10
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⣿⠉⠉⠉⠹⠿⠛⠛⠛⠛⠛⠋⠙⠛⠛⠛⠛⠛⠿⠿⠯⢭⣭⣉⣉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⠉⢉⣉⣩⣭⠭⠿⠏⠉⠉⠉⣽
# ⠀⠀⠀⠀1⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠉⠉⠛⠲⠶⢤⣄⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣤⠴⠶⠛⠋⠉⠉⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠙⠛⠲⠦⣤⣄⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣀⣤⡤⠶⠚⠛⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀0⠀⠀⠀⠀⠀⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠙⠓⠲⠶⢤⣤⣄⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣀⣀⣤⡤⠴⠶⠚⠛⠉⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠶⠿⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⣤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠭⠭⡭⠽⠿⠿⠿⠷⠶⠶⠶⠿⠿⠿⠿⠭⣭⠭⠥⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⢤⡤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⠤⣤⠤⠤⠤⠽
# −1⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠛
#
#
# ⠀⠀⠀⠀20:15:10⠀⠀⠀⠀⠀⠀⠀20:15:20⠀⠀⠀⠀⠀⠀20:15:30⠀⠀⠀⠀⠀⠀⠀20:15:40⠀⠀⠀⠀⠀⠀20:15:50⠀⠀⠀⠀⠀⠀20:16:00⠀⠀⠀⠀⠀⠀⠀20:16:10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
#      15 # plot(df_plot)
#      16 plot_terminal(df_plot)
# ---> 17 sleep(2)
#
# KeyboardInterrupt:
